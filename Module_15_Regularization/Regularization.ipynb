# %% [markdown]
# <a href="https://colab.research.google.com/github/Mitchey101/Michael/blob/main/Module_15_Regularization/Regularization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image_2021-10-30_133041.png](data:image/png;base64,...)

# %% [markdown]
# #Objective
# * To acquaint you with the problem of overfit models and to mitigate it with regularization

# %%
# Basic packages
import pandas as pd
import numpy as np
import re
import collections
import matplotlib.pyplot as plt
from pathlib import Path

# Packages for data preparation
from sklearn.model_selection import train_test_split
from nltk.corpus import stopwords
from keras.preprocessing.text import Tokenizer
from keras.utils.np_utils import to_categorical
from sklearn.preprocessing import LabelEncoder

import nltk
nltk.download('stopwords')

# Packages for modeling
import tensorflow as tf
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import regularizers

NB_WORDS = 10000  # Parameter indicating the number of words we'll put in the dictionary
NB_START_EPOCHS = 20  # Number of epochs we usually start to train with
BATCH_SIZE = 512  # Size of the batches used in the mini-batch gradient descent
MAX_LEN = 20  # Maximum number of words in a sequence

root = Path('../content/')
input_path = root / 'input/'
ouput_path = root / 'output/'
source_path = root / 'source/'

def deep_model(model, X_train, y_train, X_valid, y_valid):
    model.compile(optimizer='rmsprop'
                  , loss='categorical_crossentropy'
                  , metrics=['accuracy'])

    history = model.fit(X_train
                       , y_train
                       , epochs=NB_START_EPOCHS
                       , batch_size=BATCH_SIZE
                       , validation_data=(X_valid, y_valid)
                       , verbose=1)
    return history

def eval_metric(model, history, metric_name):
    metric = history.history[metric_name]
    val_metric = history.history['val_' + metric_name]

    e = range(1, NB_START_EPOCHS + 1)

    plt.plot(e, metric, 'bo', label='Train ' + metric_name)
    plt.plot(e, val_metric, 'b', label='Validation ' + metric_name)
    plt.xlabel('Epoch number')
    plt.ylabel(metric_name)
    plt.title('Comparing training and validation ' + metric_name + ' for ' + model.name)
    plt.legend()
    plt.show()

def remove_stopwords(input_text):
    stopwords_list = stopwords.words('english')
    # Some words which might indicate a certain sentiment are kept via a whitelist
    whitelist = ["n't", "not", "no"]
    words = input_text.split()
    clean_words = [word for word in words if (word not in stopwords_list or word in whitelist) and len(word) > 1]
    return " ".join(clean_words)

def remove_mentions(input_text):
    return re.sub(r'@\w+', '', input_text)

def test_model(model, X_train, y_train, X_test, y_test, epoch_stop):
    model.fit(X_train
              , y_train
              , epochs=epoch_stop
              , batch_size=BATCH_SIZE
              , verbose=1)
    results = model.evaluate(X_test, y_test)
    print()
    print('Test accuracy: {0:.2f}%'.format(results[1]*100))
    return results

def compare_models_by_metric(model_1, model_2, model_hist_1, model_hist_2, metric):
    metric_model_1 = model_hist_1.history[metric]
    metric_model_2 = model_hist_2.history[metric]

    e = range(1, NB_START_EPOCHS + 1)

    metrics_dict = {
        'acc' : 'Training Accuracy',
        'loss' : 'Training Loss',
        'val_acc' : 'Validation accuracy',
        'val_loss' : 'Validation loss'
    }

    metric_label = metrics_dict[metric]

    plt.plot(e, metric_model_1, 'bo', label=model_1.name)
    plt.plot(e, metric_model_2, 'b', label=model_2.name)
    plt.xlabel('Epoch number')
    plt.ylabel(metric_label)
    plt.title('Comparing ' + metric_label + ' between models')
    plt.legend()
    plt.show()

def optimal_epoch(model_hist):
    min_epoch = np.argmin(model_hist.history['val_loss']) + 1
    print("Minimum validation loss reached in epoch {}".format(min_epoch))
    return min_epoch

! gdown --id 1QFupRVBpstzf_D6NiFvYQIO-MPuiwG9u
! mkdir input/
! mv Tweets.csv input/

df = pd.read_csv(input_path / 'Tweets.csv')
df = df.reindex(np.random.permutation(df.index))
df = df[['text', 'airline_sentiment']]
df.text = df.text.apply(remove_stopwords).apply(remove_mentions)

X_train, X_test, y_train, y_test = train_test_split(df.text, df.airline_sentiment, test_size=0.1, random_state=37)

tk = Tokenizer(num_words=NB_WORDS,
               filters='!"#$%&()*+,-./:;<=>?@[\]^_`{|}~\t\n',
               lower=True,
               char_level=False,
               split=' ')
tk.fit_on_texts(X_train)

X_train_oh = tk.texts_to_matrix(X_train, mode='binary')
X_test_oh = tk.texts_to_matrix(X_test, mode='binary')

le = LabelEncoder()
y_train_le = le.fit_transform(y_train)
y_test_le = le.transform(y_test)
y_train_oh = to_categorical(y_train_le)
y_test_oh = to_categorical(y_test_le)

X_train_rest, X_valid, y_train_rest, y_valid = train_test_split(X_train_oh, y_train_oh, test_size=0.1, random_state=37)

base_model = models.Sequential()
base_model.add(layers.Dense(64, activation='relu', input_shape=(NB_WORDS,)))
base_model.add(layers.Dense(64, activation='relu'))
base_model.add(layers.Dense(3, activation='softmax'))
base_history = deep_model(base_model, X_train_rest, y_train_rest, X_valid, y_valid)
base_min = optimal_epoch(base_history)

reduced_model = models.Sequential()
reduced_model.add(layers.Dense(16, activation='relu', input_shape=(NB_WORDS,)))
reduced_model.add(layers.Dense(3, activation='softmax'))
reduced_history = deep_model(reduced_model, X_train_rest, y_train_rest, X_valid, y_valid)
reduced_min = optimal_epoch(reduced_history)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1QFupRVBpstzf_D6NiFvYQIO-MPuiwG9u
# To: /content/Tweets.csv
# 100% 3.42M/3.42M [00:00<00:00, 224MB/s]
# Epoch 1/20
# 24/24 [==============================] - 6s 41ms/step - loss: 0.8639 - accuracy: 0.6187 - val_loss: 0.7217 - val_accuracy: 0.6464
# Epoch 2/20
# 24/24 [==============================] - 1s 24ms/step - loss: 0.6479 - accuracy: 0.7136 - val_loss: 0.5979 - val_accuracy: 0.7473
# Epoch 3/20
# 24/24 [==============================] - 0s 20ms/step - loss: 0.5082 - accuracy: 0.8150 - val_loss: 0.5157 - val_accuracy: 0.7982
# Epoch 4/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.4120 - accuracy: 0.8544 - val_loss: 0.4961 - val_accuracy: 0.8005
# Epoch 5/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.3478 - accuracy: 0.8793 - val_loss: 0.4949 - val_accuracy: 0.7944
# Epoch 6/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.2973 - accuracy: 0.8971 - val_loss: 0.5130 - val_accuracy: 0.7883
# Epoch 7/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.2576 - accuracy: 0.9104 - val_loss: 0.5319 - val_accuracy: 0.7914
# Epoch 8/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.2243 - accuracy: 0.9249 - val_loss: 0.5577 - val_accuracy: 0.7921
# Epoch 9/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1943 - accuracy: 0.9356 - val_loss: 0.5955 - val_accuracy: 0.7906
# Epoch 10/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1691 - accuracy: 0.9470 - val_loss: 0.6376 - val_accuracy: 0.7944
# Epoch 11/20
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1492 - accuracy: 0.9531 - val_loss: 0.6723 - val_accuracy: 0.7785
# Epoch 12/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1299 - accuracy: 0.9591 - val_loss: 0.6965 - val_accuracy: 0.7830
# Epoch 13/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1136 - accuracy: 0.9658 - val_loss: 0.7334 - val_accuracy: 0.7731
# Epoch 14/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1000 - accuracy: 0.9693 - val_loss: 0.7813 - val_accuracy: 0.7686
# Epoch 15/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0885 - accuracy: 0.9741 - val_loss: 0.8235 - val_accuracy: 0.7807
# Epoch 16/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0785 - accuracy: 0.9767 - val_loss: 0.8626 - val_accuracy: 0.7693
# Epoch 17/20
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0701 - accuracy: 0.9801 - val_loss: 0.9049 - val_accuracy: 0.7595
# Epoch 18/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0630 - accuracy: 0.9813 - val_loss: 0.9597 - val_accuracy: 0.7724
# Epoch 19/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0568 - accuracy: 0.9836 - val_loss: 0.9822 - val_accuracy: 0.7572
# Epoch 20/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0512 - accuracy: 0.9857 - val_loss: 1.0264 - val_accuracy: 0.7618
# Minimum validation loss reached in epoch 5
# Epoch 1/20
# 24/24 [==============================] - 1s 27ms/step - loss: 0.9753 - accuracy: 0.6133 - val_loss: 0.8694 - val_accuracy: 0.6533
# Epoch 2/20
# 24/24 [==============================] - 0s 15ms/step - loss: 0.8101 - accuracy: 0.6635 - val_loss: 0.7581 - val_accuracy: 0.6874
# Epoch 3/20
# 24/24 [==============================] - 0s 19ms/step - loss: 0.7093 - accuracy: 0.7059 - val_loss: 0.6887 - val_accuracy: 0.7170
# Epoch 4/20
# 24/24 [==============================] - 1s 21ms/step - loss: 0.6373 - accuracy: 0.7437 - val_loss: 0.6391 - val_accuracy: 0.7352
# Epoch 5/20
# 24/24 [==============================] - 0s 20ms/step - loss: 0.5802 - accuracy: 0.7817 - val_loss: 0.6011 - val_accuracy: 0.7595
# Epoch 6/20
# 24/24 [==============================] - 0s 20ms/step - loss: 0.5336 - accuracy: 0.8093 - val_loss: 0.5717 - val_accuracy: 0.7792
# Epoch 7/20
# 24/24 [==============================] - 1s 24ms/step - loss: 0.4956 - accuracy: 0.8309 - val_loss: 0.5487 - val_accuracy: 0.7845
# Epoch 8/20
# 24/24 [==============================] - 0s 18ms/step - loss: 0.4634 - accuracy: 0.8437 - val_loss: 0.5309 - val_accuracy: 0.7860
# Epoch 9/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.4361 - accuracy: 0.8538 - val_loss: 0.5167 - val_accuracy: 0.7883
# Epoch 10/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.4123 - accuracy: 0.8630 - val_loss: 0.5061 - val_accuracy: 0.7951
# Epoch 11/20
# 24/24 [==============================] - 0s 15ms/step - loss: 0.3915 - accuracy: 0.8711 - val_loss: 0.5001 - val_accuracy: 0.7936
# Epoch 12/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.3733 - accuracy: 0.8770 - val_loss: 0.4946 - val_accuracy: 0.7982
# Epoch 13/20
# 24/24 [==============================] - 0s 15ms/step - loss: 0.3574 - accuracy: 0.8824 - val_loss: 0.4919 - val_accuracy: 0.8012
# Epoch 14/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.3428 - accuracy: 0.8858 - val_loss: 0.4901 - val_accuracy: 0.7967
# Epoch 15/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.3292 - accuracy: 0.8895 - val_loss: 0.4894 - val_accuracy: 0.7997
# Epoch 16/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.3163 - accuracy: 0.8955 - val_loss: 0.4904 - val_accuracy: 0.7959
# Epoch 17/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.3046 - accuracy: 0.8989 - val_loss: 0.4915 - val_accuracy: 0.7982
# Epoch 18/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.2939 - accuracy: 0.9020 - val_loss: 0.4935 - val_accuracy: 0.7929
# Epoch 19/20
# 24/24 [==============================] - 0s 15ms/step - loss: 0.2838 - accuracy: 0.9061 - val_loss: 0.4953 - val_accuracy: 0.7959
# Epoch 20/20
# 24/24 [==============================] - 0s 15ms/step - loss: 0.2744 - accuracy: 0.9088 - val_loss: 0.4972 - val_accuracy: 0.7944
# Minimum validation loss reached in epoch 15

# %% [markdown]
# # Applying regularization
#
# You may be familiar with Occam's Razor principle: given two explanations for something, the explanation most likely to be correct is the "simplest" one, the one that makes the least amount of assumptions. This also applies to the models learned by neural networks: given some training data and a network architecture, there are multiple sets of weights values (multiple models) that could explain the data, and simpler models are less likely to overfit than complex ones.
#
# A "simple model" in this context is a model where the distribution of parameter values has less entropy (or a model with fewer parameters altogether, as we saw in the section above). Thus a common way to mitigate overfitting is to put constraints on the complexity of a network by forcing its weights only to take small values, which makes the distribution of weight values more "regular". This is called "weight regularization", and it is done by adding to the loss function of the network a cost associated with having large weights. This cost comes in two flavors:
#
# L1 regularization, where the cost added is proportional to the absolute value of the weights coefficients (i.e. to what is called the "L1 norm" of the weights).
#
# L2 regularization, where the cost added is proportional to the square of the value of the weights coefficients (i.e. to what is called the squared "L2 norm" of the weights). L2 regularization is also called weight decay in the context of neural networks. Don't let the different name confuse you: weight decay is mathematically the exact same as L2 regularization.
#
# L1 regularization pushes weights towards exactly zero encouraging a sparse model. L2 regularization will penalize the weights parameters without making them sparse since the penalty goes to zero for small weights-one reason why L2 is more common.
#
# In `tf.keras`, weight regularization is added by passing weight regularizer instances to layers as keyword arguments. Let's add L2 weight regularization now.

# %%
reg_model = models.Sequential()
reg_model.add(layers.Dense(64, kernel_regularizer=regularizers.l2(0.001), activation='relu', input_shape=(NB_WORDS,)))
reg_model.add(layers.Dense(64, kernel_regularizer=regularizers.l2(0.001), activation='relu'))
reg_model.add(layers.Dense(3, activation='softmax'))
reg_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 64)                640064
#
#  dense_6 (Dense)             (None, 64)                4160
#
#  dense_7 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 644,419
# Trainable params: 644,419
# Non-trainable params: 0
# _________________________________________________________________

# %%
reg_history = deep_model(reg_model, X_train_rest, y_train_rest, X_valid, y_valid)
reg_min = optimal_epoch(reg_history)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 2s 28ms/step - loss: 1.0693 - accuracy: 0.6079 - val_loss: 0.8985 - val_accuracy: 0.6388
# Epoch 2/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.8186 - accuracy: 0.6929 - val_loss: 0.7476 - val_accuracy: 0.7413
# Epoch 3/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.6660 - accuracy: 0.8031 - val_loss: 0.6676 - val_accuracy: 0.7838
# Epoch 4/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.5676 - accuracy: 0.8425 - val_loss: 0.6259 - val_accuracy: 0.7921
# Epoch 5/20
# 24/24 [==============================] - 1s 21ms/step - loss: 0.5048 - accuracy: 0.8644 - val_loss: 0.6187 - val_accuracy: 0.7914
# Epoch 6/20
# 24/24 [==============================] - 0s 19ms/step - loss: 0.4592 - accuracy: 0.8810 - val_loss: 0.6220 - val_accuracy: 0.7929
# Epoch 7/20
# 24/24 [==============================] - 1s 21ms/step - loss: 0.4244 - accuracy: 0.8938 - val_loss: 0.6269 - val_accuracy: 0.7891
# Epoch 8/20
# 24/24 [==============================] - 1s 21ms/step - loss: 0.3963 - accuracy: 0.9017 - val_loss: 0.6273 - val_accuracy: 0.7929
# Epoch 9/20
# 24/24 [==============================] - 0s 20ms/step - loss: 0.3712 - accuracy: 0.9131 - val_loss: 0.6464 - val_accuracy: 0.7898
# Epoch 10/20
# 24/24 [==============================] - 0s 15ms/step - loss: 0.3516 - accuracy: 0.9206 - val_loss: 0.6614 - val_accuracy: 0.7951
# Epoch 11/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.3347 - accuracy: 0.9256 - val_loss: 0.6900 - val_accuracy: 0.7686
# Epoch 12/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.3191 - accuracy: 0.9346 - val_loss: 0.6934 - val_accuracy: 0.7853
# Epoch 13/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.3056 - accuracy: 0.9378 - val_loss: 0.7002 - val_accuracy: 0.7807
# Epoch 14/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.2930 - accuracy: 0.9438 - val_loss: 0.7148 - val_accuracy: 0.7762
# Epoch 15/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.2815 - accuracy: 0.9478 - val_loss: 0.7292 - val_accuracy: 0.7800
# Epoch 16/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.2713 - accuracy: 0.9520 - val_loss: 0.7550 - val_accuracy: 0.7898
# Epoch 17/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.2627 - accuracy: 0.9535 - val_loss: 0.7426 - val_accuracy: 0.7769
# Epoch 18/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.2531 - accuracy: 0.9588 - val_loss: 0.7832 - val_accuracy: 0.7845
# Epoch 19/20
# 24/24 [==============================] - 0s 18ms/step - loss: 0.2463 - accuracy: 0.9613 - val_loss: 0.7612 - val_accuracy: 0.7731
# Epoch 20/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.2407 - accuracy: 0.9598 - val_loss: 0.7874 - val_accuracy: 0.7633
# Minimum validation loss reached in epoch 5

# %% [markdown]
# For the regularized model we notice that it starts overfitting in the same epoch as the baseline model. However, the loss increases much slower afterwards.

# %%
eval_metric(reg_model, reg_history, 'loss')

# %%
compare_models_by_metric(base_model, reg_model, base_history, reg_history, 'val_loss')

# %% [markdown]
# ## Question 1
#
# First identify (provide the name of) and then code the regularizer which is used in the following loss function:
#
# $$cost = (\mathbf{y} - \mathbf{x}W)^2 + λ||W||$$
#
# Let's assume $w = [-5, 4, -3, 2, 1]$

# %% [markdown]
# ###  Answer 1

# %%
weights = [-5, 4, -3, 2, 1]

def l1_norm(weights):
    reg = lambda x: np.sum(np.abs(x))
    return reg(weights)

print(l1_norm(weights))
# Out:
# 15

# %% [markdown]
# ## Question 2
#
# First identify (provide the name of) and then code the regularizer which is used in the following loss function:
#
# $$cost = (\mathbf{y} - \mathbf{x}W)^2 + λ||W||_2^2$$
#
# Let's assume $w = [-5, 4, -3, 2, 1]$

# %% [markdown]
# ###  Answer 2

# %%
import numpy as np

weights = [-5, 4, -3, 2, 1]

def l1_norm(weights):
    reg = lambda x: np.sum(np.square(x))
    return reg(weights)

print(l1_norm(weights))
# Out:
# 55

# %% [markdown]
# ## Adding dropout layers
# Add dropout
# Dropout is one of the most effective and most commonly used regularization techniques for neural networks, developed by Hinton and his students at the University of Toronto.
#
# The intuitive explanation for dropout is that because individual nodes in the network cannot rely on the output of the others, each node must output features that are useful on their own.
#
# Dropout, applied to a layer, consists of randomly "dropping out" (i.e. set to zero) a number of output features of the layer during training. Let's say a given layer would normally have returned a vector [0.2, 0.5, 1.3, 0.8, 1.1] for a given input sample during training; after applying dropout, this vector will have a few zero entries distributed at random, e.g. [0, 0.5, 1.3, 0, 1.1].
#
# The "dropout rate" is the fraction of the features that are being zeroed-out; it is usually set between 0.2 and 0.5. At test time, no units are dropped out, and instead the layer's output values are scaled down by a factor equal to the dropout rate, so as to balance for the fact that more units are active than at training time.
#
# In `tf.keras` you can introduce dropout in a network via the Dropout layer, which gets applied to the output of layer right before.
#
# Let's add two Dropout layers in our network to see how well they do at reducing overfitting:

# %%
drop_model = models.Sequential()
drop_model.add(layers.Dense(64, activation='relu', input_shape=(NB_WORDS,)))
drop_model.add(layers.Dropout(0.5))
drop_model.add(layers.Dense(64, activation='relu'))
drop_model.add(layers.Dropout(0.5))
drop_model.add(layers.Dense(3, activation='softmax'))
drop_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 64)                640064
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_9 (Dense)             (None, 64)                4160
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_10 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 644,419
# Trainable params: 644,419
# Non-trainable params: 0
# _________________________________________________________________

# %%
drop_history = deep_model(drop_model, X_train_rest, y_train_rest, X_valid, y_valid)
drop_min = optimal_epoch(drop_history)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 2s 27ms/step - loss: 0.9293 - accuracy: 0.6004 - val_loss: 0.7726 - val_accuracy: 0.6335
# Epoch 2/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.7506 - accuracy: 0.6350 - val_loss: 0.6745 - val_accuracy: 0.6988
# Epoch 3/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.6504 - accuracy: 0.7180 - val_loss: 0.5925 - val_accuracy: 0.7602
# Epoch 4/20
# 24/24 [==============================] - 0s 18ms/step - loss: 0.5696 - accuracy: 0.7836 - val_loss: 0.5375 - val_accuracy: 0.7853
# Epoch 5/20
# 24/24 [==============================] - 0s 15ms/step - loss: 0.5023 - accuracy: 0.8211 - val_loss: 0.5057 - val_accuracy: 0.7974
# Epoch 6/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.4509 - accuracy: 0.8385 - val_loss: 0.4924 - val_accuracy: 0.8012
# Epoch 7/20
# 24/24 [==============================] - 0s 21ms/step - loss: 0.4125 - accuracy: 0.8555 - val_loss: 0.4908 - val_accuracy: 0.8088
# Epoch 8/20
# 24/24 [==============================] - 1s 22ms/step - loss: 0.3821 - accuracy: 0.8665 - val_loss: 0.4916 - val_accuracy: 0.8065
# Epoch 9/20
# 24/24 [==============================] - 1s 23ms/step - loss: 0.3506 - accuracy: 0.8779 - val_loss: 0.5011 - val_accuracy: 0.8073
# Epoch 10/20
# 24/24 [==============================] - 1s 23ms/step - loss: 0.3254 - accuracy: 0.8878 - val_loss: 0.5078 - val_accuracy: 0.8080
# Epoch 11/20
# 24/24 [==============================] - 1s 22ms/step - loss: 0.3052 - accuracy: 0.8908 - val_loss: 0.5170 - val_accuracy: 0.8027
# Epoch 12/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.2784 - accuracy: 0.9054 - val_loss: 0.5332 - val_accuracy: 0.8012
# Epoch 13/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.2634 - accuracy: 0.9098 - val_loss: 0.5442 - val_accuracy: 0.8020
# Epoch 14/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.2440 - accuracy: 0.9174 - val_loss: 0.5603 - val_accuracy: 0.8020
# Epoch 15/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.2247 - accuracy: 0.9243 - val_loss: 0.5844 - val_accuracy: 0.7951
# Epoch 16/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.2128 - accuracy: 0.9305 - val_loss: 0.5951 - val_accuracy: 0.7989
# Epoch 17/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1918 - accuracy: 0.9377 - val_loss: 0.6145 - val_accuracy: 0.7974
# Epoch 18/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1864 - accuracy: 0.9395 - val_loss: 0.6272 - val_accuracy: 0.7959
# Epoch 19/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1775 - accuracy: 0.9412 - val_loss: 0.6422 - val_accuracy: 0.7944
# Epoch 20/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1598 - accuracy: 0.9478 - val_loss: 0.6626 - val_accuracy: 0.7959
# Minimum validation loss reached in epoch 7

# %%
eval_metric(drop_model, drop_history, 'loss')

# %% [markdown]
# The model with dropout layers starts overfitting later than the baseline model. The loss also increases slower than the baseline model.

# %%
compare_models_by_metric(base_model, drop_model, base_history, drop_history, 'val_loss')

# %% [markdown]
# The model with the Dropout layers starts overfitting later. Compared to the baseline model the loss also remains much lower.

# %% [markdown]
# ## Combined L2 + dropout

# %%
combined_model = tf.keras.Sequential([
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu', input_shape=(NB_WORDS,)),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(3)
])

# %%
combined_history = deep_model(combined_model, X_train_rest, y_train_rest, X_valid, y_valid)
combined_min = optimal_epoch(combined_history)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 2s 32ms/step - loss: 1.9826 - accuracy: 0.2075 - val_loss: 1.0877 - val_accuracy: 0.1100
# Epoch 2/20
# 24/24 [==============================] - 1s 22ms/step - loss: 1.1654 - accuracy: 0.1313 - val_loss: 1.4148 - val_accuracy: 0.0865
# Epoch 3/20
# 24/24 [==============================] - 1s 21ms/step - loss: 5.6428 - accuracy: 0.0781 - val_loss: 10.6582 - val_accuracy: 0.0766
# Epoch 4/20
# 24/24 [==============================] - 0s 20ms/step - loss: 6.7163 - accuracy: 0.0832 - val_loss: 10.8054 - val_accuracy: 0.0789
# Epoch 5/20
# 24/24 [==============================] - 1s 24ms/step - loss: 7.6738 - accuracy: 0.0650 - val_loss: 9.0173 - val_accuracy: 0.1070
# Epoch 6/20
# 24/24 [==============================] - 1s 24ms/step - loss: 6.9967 - accuracy: 0.0799 - val_loss: 10.4932 - val_accuracy: 0.1282
# Epoch 7/20
# 24/24 [==============================] - 1s 25ms/step - loss: 5.7207 - accuracy: 0.1510 - val_loss: 2.8273 - val_accuracy: 0.1639
# Epoch 8/20
# 24/24 [==============================] - 1s 24ms/step - loss: 6.5426 - accuracy: 0.1607 - val_loss: 3.2987 - val_accuracy: 0.1639
# Epoch 9/20
# 24/24 [==============================] - 1s 23ms/step - loss: 9.1876 - accuracy: 0.1587 - val_loss: 10.4347 - val_accuracy: 0.1624
# Epoch 10/20
# 24/24 [==============================] - 0s 20ms/step - loss: 9.5018 - accuracy: 0.1537 - val_loss: 10.4286 - val_accuracy: 0.1624
# Epoch 11/20
# 24/24 [==============================] - 1s 21ms/step - loss: 8.9435 - accuracy: 0.1574 - val_loss: 10.8381 - val_accuracy: 0.1631
# Epoch 12/20
# 24/24 [==============================] - 1s 21ms/step - loss: 8.5607 - accuracy: 0.1590 - val_loss: 11.2721 - val_accuracy: 0.1639
# Epoch 13/20
# 24/24 [==============================] - 0s 20ms/step - loss: 8.5735 - accuracy: 0.1575 - val_loss: 11.2782 - val_accuracy: 0.1639
# Epoch 14/20
# 24/24 [==============================] - 1s 22ms/step - loss: 8.4614 - accuracy: 0.1615 - val_loss: 11.1989 - val_accuracy: 0.1639
# Epoch 15/20
# 24/24 [==============================] - 1s 21ms/step - loss: 8.4692 - accuracy: 0.1558 - val_loss: 5.6655 - val_accuracy: 0.1631
# Epoch 16/20
# 24/24 [==============================] - 0s 20ms/step - loss: 7.8287 - accuracy: 0.1552 - val_loss: 5.6722 - val_accuracy: 0.1631
# Epoch 17/20
# 24/24 [==============================] - 0s 19ms/step - loss: 7.6954 - accuracy: 0.1573 - val_loss: 5.7401 - val_accuracy: 0.1631
# Epoch 18/20
# 24/24 [==============================] - 0s 21ms/step - loss: 7.8423 - accuracy: 0.1581 - val_loss: 5.8205 - val_accuracy: 0.1631
# Epoch 19/20
# 24/24 [==============================] - 0s 20ms/step - loss: 7.8181 - accuracy: 0.1562 - val_loss: 5.8888 - val_accuracy: 0.1639
# Epoch 20/20
# 24/24 [==============================] - 0s 21ms/step - loss: 5.9123 - accuracy: 0.1601 - val_loss: 2.8023 - val_accuracy: 0.1639
# Minimum validation loss reached in epoch 1

# %%
eval_metric(combined_model, combined_history, 'loss')

# %%
compare_models_by_metric(base_model, combined_model, base_history, combined_history, 'val_loss')

# %% [markdown]
# ## Question 3
#
# When does it make sense to add both L2 regularization and Dropout?
#
# And what did doing so achieve in this case?

# %% [markdown]
# ### Answer 3
#
# Adding both L2 regularization and dropout is useful:
#
# When dealing with extremely deep neural networks with large number of parameters.
# To prevent Overfitting
# when training a model with limited training data.

# %% [markdown]
# #Training on the full train data and evaluation on test data
# At first sight the reduced model seems to be the best model for generalization. But let's check that on the test set.

# %%
base_results = test_model(base_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, base_min)
# Out:
# Epoch 1/5
# 26/26 [==============================] - 0s 15ms/step - loss: 0.1417 - accuracy: 0.9634
# Epoch 2/5
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0982 - accuracy: 0.9725
# Epoch 3/5
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0775 - accuracy: 0.9787
# Epoch 4/5
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0652 - accuracy: 0.9814
# Epoch 5/5
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0545 - accuracy: 0.9838
# 46/46 [==============================] - 0s 4ms/step - loss: 0.9997 - accuracy: 0.7794
#
# Test accuracy: 77.94%

# %%
reduced_results = test_model(reduced_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, reduced_min)
# Out:
# Epoch 1/15
# 26/26 [==============================] - 1s 20ms/step - loss: 0.2884 - accuracy: 0.9003
# Epoch 2/15
# 26/26 [==============================] - 0s 14ms/step - loss: 0.2775 - accuracy: 0.9059
# Epoch 3/15
# 26/26 [==============================] - 0s 13ms/step - loss: 0.2673 - accuracy: 0.9095
# Epoch 4/15
# 26/26 [==============================] - 0s 14ms/step - loss: 0.2583 - accuracy: 0.9120
# Epoch 5/15
# 26/26 [==============================] - 0s 14ms/step - loss: 0.2495 - accuracy: 0.9166
# Epoch 6/15
# 26/26 [==============================] - 0s 13ms/step - loss: 0.2414 - accuracy: 0.9196
# Epoch 7/15
# 26/26 [==============================] - 0s 14ms/step - loss: 0.2336 - accuracy: 0.9225
# Epoch 8/15
# 26/26 [==============================] - 0s 14ms/step - loss: 0.2264 - accuracy: 0.9252
# Epoch 9/15
# 26/26 [==============================] - 0s 14ms/step - loss: 0.2193 - accuracy: 0.9285
# Epoch 10/15
# 26/26 [==============================] - 0s 14ms/step - loss: 0.2128 - accuracy: 0.9307
# Epoch 11/15
# 26/26 [==============================] - 0s 14ms/step - loss: 0.2064 - accuracy: 0.9333
# Epoch 12/15
# 26/26 [==============================] - 0s 14ms/step - loss: 0.2007 - accuracy: 0.9355
# Epoch 13/15
# 26/26 [==============================] - 0s 13ms/step - loss: 0.1947 - accuracy: 0.9376
# Epoch 14/15
# 26/26 [==============================] - 0s 13ms/step - loss: 0.1892 - accuracy: 0.9393
# Epoch 15/15
# 26/26 [==============================] - 0s 13ms/step - loss: 0.1838 - accuracy: 0.9402
# 46/46 [==============================] - 0s 3ms/step - loss: 0.5572 - accuracy: 0.7985
#
# Test accuracy: 79.85%

# %%
reg_results = test_model(reg_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, reg_min)
# Out:
# Epoch 1/5
# 26/26 [==============================] - 1s 20ms/step - loss: 0.2885 - accuracy: 0.9442
# Epoch 2/5
# 26/26 [==============================] - 0s 17ms/step - loss: 0.2603 - accuracy: 0.9518
# Epoch 3/5
# 26/26 [==============================] - 0s 17ms/step - loss: 0.2466 - accuracy: 0.9576
# Epoch 4/5
# 26/26 [==============================] - 0s 14ms/step - loss: 0.2347 - accuracy: 0.9624
# Epoch 5/5
# 26/26 [==============================] - 0s 14ms/step - loss: 0.2287 - accuracy: 0.9633
# 46/46 [==============================] - 0s 3ms/step - loss: 0.7496 - accuracy: 0.7801
#
# Test accuracy: 78.01%

# %%
drop_results = test_model(drop_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, drop_min)
# Out:
# Epoch 1/7
# 26/26 [==============================] - 0s 15ms/step - loss: 0.2026 - accuracy: 0.9348
# Epoch 2/7
# 26/26 [==============================] - 0s 15ms/step - loss: 0.1818 - accuracy: 0.9441
# Epoch 3/7
# 26/26 [==============================] - 0s 14ms/step - loss: 0.1722 - accuracy: 0.9464
# Epoch 4/7
# 26/26 [==============================] - 0s 14ms/step - loss: 0.1607 - accuracy: 0.9492
# Epoch 5/7
# 26/26 [==============================] - 0s 14ms/step - loss: 0.1479 - accuracy: 0.9531
# Epoch 6/7
# 26/26 [==============================] - 0s 14ms/step - loss: 0.1379 - accuracy: 0.9557
# Epoch 7/7
# 26/26 [==============================] - 0s 13ms/step - loss: 0.1299 - accuracy: 0.9587
# 46/46 [==============================] - 0s 3ms/step - loss: 0.7613 - accuracy: 0.7964
#
# Test accuracy: 79.64%

# %% [markdown]
# # Handling Underfitting
# * In a general situation, the best strategy is to increase the model complexity by either increasing the number of parameters of your deep learning model or the order of your model. Underfitting is due to the model being simpler than needed. It fails to capture the patterns in the data. Increasing the model complexity will lead to improvement in training performance. If we use a large enough model it can even achieve a training error of zero i.e. the model will memorize the data and suffer from over-fitting. The goal is to hit the optimal sweet spot.
# * Try to train the model for more epochs. Ensure that the loss is decreasing gradually over the course of the training. Otherwise, it is highly likely that there is some kind of bug or problem in the training code/logic itself.
# * If you aren’t shuffling the data after every epoch, it can harm the model performance. Ensuring that you are shuffling the data is a good check to perform at this point.

# %% [markdown]
# #Conclusion
# To recap: here are the most common ways to prevent overfitting in neural networks:
#
# * Get more training data.
# * Reduce the capacity of the network.
# * Add weight regularization.
# * Add dropout.
#
# Two important approaches not covered in this guide are:
#
# * data-augmentation
# * batch normalization
#
# Remember that each method can help on its own, but often combining them can be even more effective.
#
# here are the ways to prevent underfitting
#
# * Get more training data.
# * Increase the size or number of parameters in the model.
# * Increase the complexity of the model.
# * Increasing the training time, until cost function is minimised.

# %% [markdown]
# # Bonus content - Visualizing L2 regularization

# %%
import numpy as np
#%matplotlib notebook
# %matplotlib inline
import matplotlib.pyplot as plt
from IPython.core.debugger import set_trace
import warnings
warnings.filterwarnings('ignore')
import itertools

# %%
def plot_contour(f, x1bound, x2bound, resolution, ax):
    x1range = np.linspace(x1bound[0], x1bound[1], resolution)
    x2range = np.linspace(x2bound[0], x2bound[1], resolution)
    xg, yg = np.meshgrid(x1range, x2range)
    zg = np.zeros_like(xg)
    for i,j in itertools.product(range(resolution), range(resolution)):
        zg[i,j] = f([xg[i,j], yg[i,j]])
    ax.contour(xg, yg, zg, 100)
    return ax

# %% [markdown]
# Let's create a toy data:

# %%
N = 20
x = np.random.rand(N) * 10
y = -4*x + 10 + 2*np.random.randn(N)

# %% [markdown]
# visualize the regularized **cost function**

# %%
cost = lambda w: .5*np.mean((w[0] + w[1]*x - y)**2)
l2_penalty = lambda w: np.dot(w,w)/2
cost_plus_l2 = lambda w: cost(w) + 5*l2_penalty(w)

fig, axes = plt.subplots(ncols=3, nrows=1, constrained_layout=True, figsize=(15, 5))
plot_contour(cost, [-20,20], [-20,20], 50, axes[0])
axes[0].set_title(r'cost function $J(w)$')
plot_contour(l2_penalty, [-20,20], [-20,20], 50, axes[1])
axes[1].set_title(r'L2 reg. $||w||_2^2$')
plot_contour(cost_plus_l2, [-20,20], [-20,20], 50, axes[2])
axes[2].set_title(r'L2 reg. cost $J(w) + 5 ||w||_2^2$')
plt.show()

# %% [markdown]
# ## Bonus Question 1
#
# Plot the same for L1 regularization

# %% [markdown]
# ### Answer

# %%
cost = lambda w: .5 * np.mean((w[0] + w[1] * x - y) ** 2)
l1_penalty = lambda w: np.sum(np.abs(w)) / 2
cost_plus_l1 = lambda w: cost(w) + 5 * l1_penalty(w)

fig, axes = plt.subplots(ncols=3, nrows=1, constrained_layout=True, figsize=(15, 5))
plot_contour(cost, [-20,20], [-20,20], 50, axes[0])
axes[0].set_title(r'cost function $J(w)$')
plot_contour(l1_penalty, [-20,20], [-20,20], 50, axes[1])
axes[1].set_title(r'L1 reg. $||w||_2^2$')
plot_contour(cost_plus_l1, [-20,20], [-20,20], 50, axes[2])
axes[2].set_title(r'L1 reg. cost $J(w) + 5 ||w||')
plt.show()

# %% [markdown]
# ## Bonus Question 2
# After looking at the visualization to what the L1 and L2 normalizations, how do they help while training?
#
# \<*Type your answer here*\>

# %% [markdown]
# # Upload this Colab Notebook to your Github repository. Also add your *reflections* on today's learning in README.md
